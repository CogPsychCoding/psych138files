# %% [markdown]
# <a href="https://colab.research.google.com/github/CogPsychCoding/psych138files/blob/main/Lectures/Lecture1/Lecture1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %% [markdown]
# Note: This is necessary to init image presentation and access to files on google drive.

# %%
from IPython.display import Image
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Quick test of drive access by listing files in target folder

# %%
# !ls drive/MyDrive/0_Psych138/Lectures/Lecture1
# Out:
# ComputerOverview.png  temp.ipynb

# %% [markdown]
# # Syllabus

# %%
Image("drive/MyDrive/0_Psych138/Lectures/Lecture1/bit.ly_Psych138Syllabus2023.png", width=640)

# %% [markdown]
# # Alternative to IDLE

# %% [markdown]
# The book/video assumes you're using IDLE
#
# - REPL (read-eval-print-loop)
# - Code Files (Saveable text files containing code)
#
# We're going to use Jupyter Notebooks (in Google Colab) instead.

# %% [markdown]
# # Computer Overview

# %%
Image("drive/MyDrive/0_Psych138/Lectures/Lecture1/ComputerOverview.png")

# %% [markdown]
# [link text](https://)# New Section

# %% [markdown]
# # Why Python?

# %% [markdown]
# C Code

# %%
#include <stdio.h>
#include <stdlib.h>

int main() {
    // Create an array of strings containing the words "one" through "nine"
    char *words[] = {"one", "two", "three", "four", "five", "six", "seven", "eight", "nine"};

    // Calculate the number of words in the array
    int numWords = sizeof(words) / sizeof(words[0]);

    // Loop through the array and print each word
    for (int i = 0; i < numWords; i++) {
        printf("%s\n", words[i]);
    }

    return 0;
}

# %% [markdown]
# C++ Code

# %%
#include <iostream>
#include <vector>
#include <string>

int main() {
    // Create a vector of strings containing the words "one" through "nine"
    std::vector<std::string> words = {"one", "two", "three", "four", "five", "six", "seven", "eight", "nine"};

    // Loop through the vector and print each word
    for (const std::string& word : words) {
        std::cout << word << std::endl;
    }

    return 0;
}

# %% [markdown]
# Java Code

# %%
public class Main {
    public static void main(String[] args) {
        // Create an array of strings containing the words "one" through "nine"
        String[] words = {"one", "two", "three", "four", "five", "six", "seven", "eight", "nine"};

        // Loop through the array and print each word
        for (String word : words) {
            System.out.println(word);
        }
    }
}

# %% [markdown]
# Python Code

# %%
# Create a list of strings containing the words "one" through "nine"
words = ["one", "two", "three", "four", "five", "six", "seven", "eight", "nine"]

# Loop through the list and print each word
for word in words:
    print(word)

word = 8 * 4
print(word)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight
# nine
# 32

# %%
j8 _ 82
# Out:
#   File "<ipython-input-8-7f2b31b1ec70>", line 1
#     j8 _ 82
#        ^
# SyntaxError: invalid syntax
